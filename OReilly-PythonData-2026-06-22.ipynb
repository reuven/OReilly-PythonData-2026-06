# %% [markdown]
# # Agenda, week 3
#
# 1. Q&A
# 2. Sorting
# 3. Grouping (basic, advanced)
# 4. Pivot tables
# 5. Joining
# 6. Cleaning our data
# 7. Plotting
# 8. AMA (ask me anything)
# 9. What's next?

# %% [markdown]
# # Sorting
#
# What does it mean to *sort* our data?
#
# - We want to order it, typically from smallest to largest *or* from largest to smallest
# - When it comes to data in Pandas, we have many more options than just those

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_csv('taxi.csv',                          # load the 10k taxi records
                 index_col=['tpep_pickup_datetime'])  # when creating the data frame, make the pickup datetime the index

df
# Out:
#                       VendorID tpep_dropoff_datetime  passenger_count  \
# tpep_pickup_datetime
# 2015-06-02 11:19:29          2   2015-06-02 11:47:52                1
# 2015-06-02 11:19:30          2   2015-06-02 11:27:56                1
# 2015-06-02 11:19:31          2   2015-06-02 11:30:30                1
# 2015-06-02 11:19:31          2   2015-06-02 11:39:02                1
# 2015-06-02 11:19:32          1   2015-06-02 11:32:49                1
# ...                        ...                   ...              ...
# 2015-06-01 00:12:59          1   2015-06-01 00:24:18                1
# 2015-06-01 00:12:59          1   2015-06-01 00:28:16                1
# 2015-06-01 00:13:00          2   2015-06-01 00:37:25                1
# 2015-06-01 00:13:02          2   2015-06-01 00:19:10                6
# 2015-06-01 00:13:04          1   2015-06-01 00:36:33                1
#
#                       trip_distance  pickup_longitude  pickup_latitude  \
# tpep_pickup_datetime
# ...

# %%
# I want to find the shortest trip distances
# I can grab the trip_distance column and run min on it

df['trip_distance'].min()
# Out:
# np.float64(0.0)

# %%
# what about the 5 shortest or the 10 shortest?
# to most easily do this, we will invoke the sort_values method on the series

df['trip_distance'].sort_values()  # this returns a new series, based on the original, sorted in ascending order
# Out:
# tpep_pickup_datetime
# 2015-06-01 00:12:13     0.00
# 2015-06-04 15:18:09     0.00
# 2015-06-02 11:23:46     0.00
# 2015-06-01 00:08:03     0.00
# 2015-06-01 00:07:43     0.00
#                        ...
# 2015-06-04 15:17:25    34.84
# 2015-06-02 11:21:03    35.51
# 2015-06-01 00:02:42    37.20
# 2015-06-01 00:04:50    60.30
# 2015-06-01 00:00:58    64.60
# Name: trip_distance, Length: 9999, dtype: float64

# %%
df['trip_distance'].sort_values().head(5)  # get the 5 smallest values
# Out:
# tpep_pickup_datetime
# 2015-06-01 00:12:13    0.0
# 2015-06-04 15:18:09    0.0
# 2015-06-02 11:23:46    0.0
# 2015-06-01 00:08:03    0.0
# 2015-06-01 00:07:43    0.0
# Name: trip_distance, dtype: float64

# %%
df['trip_distance'].sort_values().head(15)
# Out:
# tpep_pickup_datetime
# 2015-06-01 00:12:13    0.0
# 2015-06-04 15:18:09    0.0
# 2015-06-02 11:23:46    0.0
# 2015-06-01 00:08:03    0.0
# 2015-06-01 00:07:43    0.0
# 2015-06-04 15:23:02    0.0
# 2015-06-06 16:51:57    0.0
# 2015-06-04 15:18:40    0.0
# 2015-06-01 00:03:44    0.0
# 2015-06-04 15:17:31    0.0
# 2015-06-02 11:21:38    0.0
# 2015-06-02 11:32:13    0.0
# 2015-06-06 16:53:43    0.0
# 2015-06-01 00:05:05    0.0
# 2015-06-02 11:31:47    0.0
# Name: trip_distance, dtype: float64

# %%
# what about the largest values?

df['trip_distance'].sort_values().tail(15)  # keep the sort in ascending order, and get the largest (ending) values
# Out:
# tpep_pickup_datetime
# 2015-06-04 15:23:01    26.60
# 2015-06-02 11:29:58    27.35
# 2015-06-02 11:26:23    27.81
# 2015-06-02 11:25:26    28.80
# 2015-06-01 00:09:29    29.30
# 2015-06-01 00:00:16    29.78
# 2015-06-01 00:09:14    31.50
# 2015-06-01 00:00:13    31.90
# 2015-06-02 11:28:58    32.10
# 2015-06-01 00:01:19    32.40
# 2015-06-04 15:17:25    34.84
# 2015-06-02 11:21:03    35.51
# 2015-06-01 00:02:42    37.20
# 2015-06-01 00:04:50    60.30
# 2015-06-01 00:00:58    64.60
# Name: trip_distance, dtype: float64

# %%
# another option: sort in *descending* order

df['trip_distance'].sort_values(ascending=False).head(5) # take the first 5 elements/value, after sorting in descending order
# Out:
# tpep_pickup_datetime
# 2015-06-01 00:00:58    64.60
# 2015-06-01 00:04:50    60.30
# 2015-06-01 00:02:42    37.20
# 2015-06-02 11:21:03    35.51
# 2015-06-04 15:17:25    34.84
# Name: trip_distance, dtype: float64

# %% [markdown]
# # Even more sorting!
#
# It's natural to understand what `sort_values` does. But there's another way to sort a data frame (or series) in Pandas, that is to sort the *index*. For that, we have a separate `sort_index` method. The result is a series in which the index is sorted, and the values just come along for the ride.

# %%
df['trip_distance'].sort_index()  # we'll get back a new series in which the trips are from earliest to latest.
# Out:
# tpep_pickup_datetime
# 2015-06-01 00:00:00     1.00
# 2015-06-01 00:00:00     1.40
# 2015-06-01 00:00:00     0.90
# 2015-06-01 00:00:01     8.15
# 2015-06-01 00:00:01     1.20
#                        ...
# 2015-06-06 16:53:56     1.20
# 2015-06-06 16:53:56     1.30
# 2015-06-06 16:53:56    17.36
# 2015-06-06 16:53:56     0.58
# 2015-06-06 16:53:57     0.50
# Name: trip_distance, Length: 9999, dtype: float64

# %% [markdown]
# # When to use each one?
#
# - If you want the largest/smallest values, then `sort_values` is more appropriate and useful.
# - If you want to get the values sorted by datetime, or user ID, or address, then you can make that column into the index, and run `sort_index`.

# %% [markdown]
# # What about sorting data frames?
#
# Generally speaking, every method that's available on a series is also available on a data frame.
#
# - `sort_index` is easier to understand on a data frame; it works just like on a series, but multiple columns come along for the ride.
# - `sort_values` is more complex, because you have many values that you could sort by. You have to specify to Pandas which column you want to sort by.

# %%
df.sort_index()
# Out:
#                       VendorID tpep_dropoff_datetime  passenger_count  \
# tpep_pickup_datetime
# 2015-06-01 00:00:00          1   2015-06-01 00:06:12                1
# 2015-06-01 00:00:00          2   2015-06-01 00:00:00                2
# 2015-06-01 00:00:00          2   2015-06-01 00:00:00                1
# 2015-06-01 00:00:01          2   2015-06-01 00:24:48                1
# 2015-06-01 00:00:01          1   2015-06-01 00:08:26                3
# ...                        ...                   ...              ...
# 2015-06-06 16:53:56          1   2015-06-06 17:00:40                1
# 2015-06-06 16:53:56          1   2015-06-06 17:00:10                1
# 2015-06-06 16:53:56          2   2015-06-06 17:54:22                1
# 2015-06-06 16:53:56          2   2015-06-06 16:56:18                1
# 2015-06-06 16:53:57          1   2015-06-06 16:58:39                1
#
#                       trip_distance  pickup_longitude  pickup_latitude  \
# tpep_pickup_datetime
# ...

# %%
df.sort_values('trip_distance')
# Out:
#                       VendorID tpep_dropoff_datetime  passenger_count  \
# tpep_pickup_datetime
# 2015-06-01 00:12:13          1   2015-06-01 00:13:47                1
# 2015-06-04 15:18:09          1   2015-06-04 15:18:09                2
# 2015-06-02 11:23:46          2   2015-06-02 11:24:07                4
# 2015-06-01 00:08:03          2   2015-06-01 00:08:08                1
# 2015-06-01 00:07:43          1   2015-06-01 00:07:43                1
# ...                        ...                   ...              ...
# 2015-06-04 15:17:25          2   2015-06-04 17:05:42                1
# 2015-06-02 11:21:03          2   2015-06-02 12:16:47                1
# 2015-06-01 00:02:42          1   2015-06-01 00:03:38                1
# 2015-06-01 00:04:50          1   2015-06-01 01:31:44                1
# 2015-06-01 00:00:58          1   2015-06-01 01:22:05                1
#
#                       trip_distance  pickup_longitude  pickup_latitude  \
# tpep_pickup_datetime
# ...

# %%
# What if I want the dropoff times for the 5 longest trips?

(
    df
    .sort_values('trip_distance')  # sort by the trip distance, in ascending order
    ['tpep_dropoff_datetime']      # grab the one column that's of interest to us
    .tail(5)                       # get the 5 final values, corresponding to the largest trip_distance
)
# Out:
# tpep_pickup_datetime
# 2015-06-04 15:17:25    2015-06-04 17:05:42
# 2015-06-02 11:21:03    2015-06-02 12:16:47
# 2015-06-01 00:02:42    2015-06-01 00:03:38
# 2015-06-01 00:04:50    2015-06-01 01:31:44
# 2015-06-01 00:00:58    2015-06-01 01:22:05
# Name: tpep_dropoff_datetime, dtype: str

# %% [markdown]
# # Can we sort by more than one column?
#
# We saw that when we invoke `sort_values`, we can pass a column name. We've seen, though, that wherever you can pass a single column name (a string) in Pandas, you can also pass a list of column names (a list of strings). We can do that here, too!

# %%
(
    df
    .sort_values(['trip_distance', 'total_amount'])  # if two trips have the same trip_distance, then total_amount will break the tie
)
# Out:
#                       VendorID tpep_dropoff_datetime  passenger_count  \
# tpep_pickup_datetime
# 2015-06-02 11:24:35          2   2015-06-02 11:24:40                1
# 2015-06-02 11:20:23          2   2015-06-02 11:20:23                2
# 2015-06-02 11:19:46          1   2015-06-02 12:26:33                1
# 2015-06-02 11:24:35          2   2015-06-02 11:24:40                1
# 2015-06-02 11:23:46          2   2015-06-02 11:24:07                4
# ...                        ...                   ...              ...
# 2015-06-04 15:17:25          2   2015-06-04 17:05:42                1
# 2015-06-02 11:21:03          2   2015-06-02 12:16:47                1
# 2015-06-01 00:02:42          1   2015-06-01 00:03:38                1
# 2015-06-01 00:04:50          1   2015-06-01 01:31:44                1
# 2015-06-01 00:00:58          1   2015-06-01 01:22:05                1
#
#                       trip_distance  pickup_longitude  pickup_latitude  \
# tpep_pickup_datetime
# ...

# %% [markdown]
# # Two more sorting methods
#
# These methods are shortcuts for sorting + grabbing the largest and smallest values:
#
# - `nlargest` -- `df.nlargest(columns='trip_distance', n=10)` -- this returns the rows with the 10 largest `trip_distance` values
# - `nsmallest`

# %%
df.nlargest(columns='trip_distance', n=10)
# Out:
#                       VendorID tpep_dropoff_datetime  passenger_count  \
# tpep_pickup_datetime
# 2015-06-01 00:00:58          1   2015-06-01 01:22:05                1
# 2015-06-01 00:04:50          1   2015-06-01 01:31:44                1
# 2015-06-01 00:02:42          1   2015-06-01 00:03:38                1
# 2015-06-02 11:21:03          2   2015-06-02 12:16:47                1
# 2015-06-04 15:17:25          2   2015-06-04 17:05:42                1
# 2015-06-01 00:01:19          2   2015-06-01 00:40:12                1
# 2015-06-02 11:28:58          1   2015-06-02 12:13:29                1
# 2015-06-01 00:00:13          1   2015-06-01 00:41:05                1
# 2015-06-01 00:09:14          1   2015-06-01 01:03:11                1
# 2015-06-01 00:00:16          2   2015-06-01 00:40:35                2
#
#                       trip_distance  pickup_longitude  pickup_latitude  \
# tpep_pickup_datetime
# 2015-06-01 00:00:58           64.60          0.000000         0.000000
# ...

# %% [markdown]
# # Exercise: Olympic records
#
# This exercise uses a CSV file, `https://files.lerner.co.il/olympic_athlete_events.zip`, with all Olympic athletes until 2020.
#
# 1. Load this file into a Pandas data frame.
# 2. Find the 10 heaviest athletes ever to compete. What were their names? What teams did they play for?
# 3. Find the 10 shortest athletes. How old were they, on average?

# %%
filename = 'olympic_athlete_events.zip'

# read_csv works just fine with zipfiles, if they contain csv!
df = pd.read_csv(filename,
                usecols=['Weight', 'Team', 'Name', 'Height', 'Age'])  # usecols lets us determine what columns are read + put into a data frame
df
# Out:
#                             Name   Age  Height  Weight            Team
# 0                      A Dijiang  24.0   180.0    80.0           China
# 1                       A Lamusi  23.0   170.0    60.0           China
# 2            Gunnar Nielsen Aaby  24.0     NaN     NaN         Denmark
# 3           Edgar Lindenau Aabye  34.0     NaN     NaN  Denmark/Sweden
# 4       Christine Jacoba Aaftink  21.0   185.0    82.0     Netherlands
# ...                          ...   ...     ...     ...             ...
# 271111                Andrzej ya  29.0   179.0    89.0        Poland-1
# 271112                  Piotr ya  27.0   176.0    59.0          Poland
# 271113                  Piotr ya  27.0   176.0    59.0          Poland
# 271114        Tomasz Ireneusz ya  30.0   185.0    96.0          Poland
# 271115        Tomasz Ireneusz ya  34.0   185.0    96.0          Poland
#
# [271116 rows x 5 columns]

# %%
# Find the 10 heaviest athletes ever to compete. What were their names? What teams did they play for?

(
    df
    .sort_values('Weight', ascending=False)
    .head(10)
)
# Out:
#                                  Name   Age  Height  Weight           Team
# 23156               Ricardo Blas, Jr.  25.0   183.0   214.0           Guam
# 23155               Ricardo Blas, Jr.  21.0   183.0   214.0           Guam
# 205467              Aytami Ruano Vega  27.0   200.0   198.0          Spain
# 75031                   Marek Galiski  29.0   200.0   190.0         Poland
# 237040  Christopher J. "Chris" Taylor  22.0   196.0   182.0  United States
# 237039  Christopher J. "Chris" Taylor  22.0   196.0   182.0  United States
# 206352             Valentyn Rusliakov  28.0   187.0   180.0        Ukraine
# 206004    Leonel Wilfredo Ruz Carmona  29.0   187.0   178.0      Venezuela
# 94363     Marcus Jerrold "Mark" Henry  25.0   190.0   176.5  United States
# 94362     Marcus Jerrold "Mark" Henry  21.0   190.0   176.5  United States

# %%
(
    df
    .nlargest(columns='Weight', n=10)
)
# Out:
#                                  Name   Age  Height  Weight           Team
# 23155               Ricardo Blas, Jr.  21.0   183.0   214.0           Guam
# 23156               Ricardo Blas, Jr.  25.0   183.0   214.0           Guam
# 205467              Aytami Ruano Vega  27.0   200.0   198.0          Spain
# 75031                   Marek Galiski  29.0   200.0   190.0         Poland
# 237039  Christopher J. "Chris" Taylor  22.0   196.0   182.0  United States
# 237040  Christopher J. "Chris" Taylor  22.0   196.0   182.0  United States
# 206352             Valentyn Rusliakov  28.0   187.0   180.0        Ukraine
# 206004    Leonel Wilfredo Ruz Carmona  29.0   187.0   178.0      Venezuela
# 94362     Marcus Jerrold "Mark" Henry  21.0   190.0   176.5  United States
# 94363     Marcus Jerrold "Mark" Henry  25.0   190.0   176.5  United States

# %%
# Find the 10 shortest athletes. How old were they, on average?

(
    df
    .nsmallest(columns='Height', n=10)
    ['Age']
     .mean()
)
# Out:
# np.float64(18.6)

# %%
# we can use the drop_duplicates method to ... remove duplicates

(
    df
    .nlargest(columns='Weight', n=10)
    .drop_duplicates(subset=['Name', 'Team'])
)
# Out:
#                                  Name   Age  Height  Weight           Team
# 23155               Ricardo Blas, Jr.  21.0   183.0   214.0           Guam
# 205467              Aytami Ruano Vega  27.0   200.0   198.0          Spain
# 75031                   Marek Galiski  29.0   200.0   190.0         Poland
# 237039  Christopher J. "Chris" Taylor  22.0   196.0   182.0  United States
# 206352             Valentyn Rusliakov  28.0   187.0   180.0        Ukraine
# 206004    Leonel Wilfredo Ruz Carmona  29.0   187.0   178.0      Venezuela
# 94362     Marcus Jerrold "Mark" Henry  21.0   190.0   176.5  United States

# %%
help(df.drop_duplicates)
# Out:
# Help on method drop_duplicates in module pandas.core.frame:
#
# drop_duplicates(
#     subset: Hashable | Iterable[Hashable] | None = None,
#     *,
#     keep: DropKeep = 'first',
#     inplace: bool = False,
#     ignore_index: bool = False
# ) -> DataFrame | None method of pandas.DataFrame instance
#     Return DataFrame with duplicate rows removed.
#
#     Considering certain columns is optional. Indexes, including time indexes
#     are ignored.
#
#     Parameters
#     ----------
#     subset : column label or iterable of labels, optional
#         Only consider certain columns for identifying duplicates, by
#         default use all of the columns.
#     keep : {'first', 'last', ``False``}, default 'first'
#         Determines which duplicates (if any) to keep.
#
#         - 'first' : Drop duplicates except for the first occurrence.
#         - 'last' : Drop duplicates except for the last occurrence.
#         - ``False`` : Drop all duplicates.
#
# ...

# %% [markdown]
# # Grouping
#
# Let's say that I have the taxi data loaded up, and I want to know, for rides with 1 passenger, what was the mean `trip_distance`?

# %%
df = pd.read_csv('taxi.csv')

(
    df
    .loc[ pd.col('passenger_count') == 1 ]   #  replaces this: .loc[ df['passenger_count'] == 1 ]
    ['trip_distance']
    .mean()
)
# Out:
# np.float64(3.0923380047176354)

# %%
# now do it for trips with 2 passengers

(
    df
    .loc[ pd.col('passenger_count') == 2 ] 
    ['trip_distance']
    .mean()
)
# Out:
# np.float64(3.3843869002284848)

# %%
# now do it for trips with 3 passengers

(
    df
    .loc[ pd.col('passenger_count') == 3 ] 
    ['trip_distance']
    .mean()
)
# Out:
# np.float64(3.3423891625615765)

# %% [markdown]
# # Grouping is precisely for this problem:
#
# - We have a categorical column with a number of distinct values
# - We also have a column with numeric values
# - We want to perform an aggregation/calculation for each distinct categorical value, running on the numeric values
#
# For example: I want the mean of `trip_distance` for each distinct value of `passenger_count`

# %%
#             categorical       numeric         aggregation method
df.groupby('passenger_count')['trip_distance'].mean()
# Out:
# passenger_count
# 0    4.600000
# 1    3.092338
# 2    3.384387
# 3    3.342389
# 4    3.628901
# 5    3.182712
# 6    3.170976
# Name: trip_distance, dtype: float64

# %% [markdown]
# # Examples of where/how to use grouping
#
# - For each country, what was the total number of sales?
# - For each salesperson, what was the mean number of sales this year?
# - For each product, what is the max price?
#
# You'll always need an aggregation method, typically: `mean`, `median`, `max`, `min`, `sum`, `count`

# %% [markdown]
# # Exercise: Olympic grouping
#
# 1. For each team, what was the mean athlete height? Which 5 teams were tallest, on average?
# 2. For each team, what was the number of medals they accumulated? Note that the `count` method ignores `NaN`.

# %%
olympics_df = pd.read_csv('olympic_athlete_events.zip')

# %%
# For each team, what was the mean athlete height? Which 5 teams were tallest, on average?

# - categorical - team, I want one result for each unique team name
# - numeric - Height
# - aggregation method will be mean

olympics_df.groupby('Team')['Height'].mean()  # this returns a series -- index is team names, values are mean height for each team
# Out:
# Team
# 30. Februar              171.500000
# A North American Team           NaN
# Acipactli                174.666667
# Acturus                         NaN
# Afghanistan              170.592593
#                             ...
# Zambia                   172.828125
# Zefyros                  180.000000
# Zimbabwe                 173.325175
# Zut                             NaN
# rn-2                     176.000000
# Name: Height, Length: 1184, dtype: float64

# %%
# on a series, we can invoke nlargest, but there are columns, so we just pass a number

(
    olympics_df
    .groupby('Team')['Height'].mean()
    .nlargest(5)
)
# Out:
# Team
# Puerto Rico-1           196.000000
# England-1               193.000000
# France/Great Britain    191.000000
# Nadine                  190.000000
# Ireland-1               189.666667
# Name: Height, dtype: float64

# %%
# For each team, what was the number of medals they accumulated? Note that the count method ignores NaN.

# categorical - Team
# to-be-calculated - Medal
# aggregation method - count

(
    olympics_df
    .groupby('Team')['Medal'].count()
    .nlargest(10)
)
# Out:
# Team
# United States    5219
# Soviet Union     2451
# Germany          1984
# Great Britain    1673
# France           1550
# Italy            1527
# Sweden           1434
# Australia        1306
# Canada           1243
# Hungary          1127
# Name: Medal, dtype: int64

# %% [markdown]
# # Next up
#
# - More grouping
# - Pivot tables

# %% [markdown]
# If you can say, "for every _____, calculate the ____," then that's a `groupby`.
#
# We can be more sophisticated in our grouping, too.

# %%
# we want to get the mean trip_distance for every distinct value of passenger_count

#             categorical       numeric         agg method
df.groupby('passenger_count')['trip_distance'].mean()
# Out:
# passenger_count
# 0    4.600000
# 1    3.092338
# 2    3.384387
# 3    3.342389
# 4    3.628901
# 5    3.182712
# 6    3.170976
# Name: trip_distance, dtype: float64

# %%
# what if I want to get the mean trip_distance and *also* the mean total_amount?

df.groupby('passenger_count')['total_amount'].mean()
# Out:
# passenger_count
# 0    25.570000
# 1    17.368569
# 2    18.406306
# 3    17.994704
# 4    18.881648
# 5    17.211269
# 6    17.401355
# Name: total_amount, dtype: float64

# %%
# we can provide a list of columns inside of the [] -- so yes, we'll have [[ ]]

#            categorical        list of numeric columns          agg method
df.groupby('passenger_count')[['trip_distance', 'total_amount']].mean()
# Out:
#                  trip_distance  total_amount
# passenger_count
# 0                     4.600000     25.570000
# 1                     3.092338     17.368569
# 2                     3.384387     18.406306
# 3                     3.342389     17.994704
# 4                     3.628901     18.881648
# 5                     3.182712     17.211269
# 6                     3.170976     17.401355

# %% [markdown]
# # Examples of how we might use this
#
# - For each country, what were the median population and income?
# - For each city, what is are the mean family size and sq meters/feet per home?

# %%
# What if we want to calculate more than one aggregation method?
# then ... we just put a list there!

#            categorical       numeric            agg methods -- two of them!
df.groupby('passenger_count')['trip_distance'].agg(['mean', 'std'])
# Out:
#                      mean       std
# passenger_count
# 0                4.600000  4.666905
# 1                3.092338  4.020187
# 2                3.384387  4.242826
# 3                3.342389  3.822041
# 4                3.628901  4.351369
# 5                3.182712  3.969468
# 6                3.170976  3.759807

# %%
# we can also provide a list of categorical columns
# in this case, I get back a series *but* the index has two parts!
# this is known as a multi-index

df.groupby(['passenger_count', 'VendorID'])['trip_distance'].mean()
# Out:
# passenger_count  VendorID
# 0                1           4.600000
# 1                1           2.956456
#                  2           3.262967
# 2                1           3.452027
#                  2           3.328849
# 3                1           3.588535
#                  2           3.187189
# 4                1           3.952239
#                  2           3.440522
# 5                1           4.933333
#                  2           3.172553
# 6                2           3.170976
# Name: trip_distance, dtype: float64

# %% [markdown]
# # Bottom line:
#
# - we can have 1 or more categoricals
# - we can have 1 or more data/numeric columns
# - we can have 1 or more aggregation methods
#
# Can we have multiples of more than one of these? YES, but then it gets very complex.

# %% [markdown]
# # Exercise: Olympic grouping
#
# 1. Load the Olympic data into a data frame.
# 2. For each sport, find the mean height and weight.
# 3. For each combination of year and season, find the mean height
# 4. For each sport, find the mean + std height.

# %%
olympics_df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# For each sport, find the mean height and weight.

# categorical - sport
# numeric/data - Height + Weight
# agg function: mean

olympics_df.groupby('Sport')[['Height', 'Weight']].mean()
# Out:
#                       Height     Weight
# Sport
# Aeronautics              NaN        NaN
# Alpine Skiing     173.489052  72.068110
# Alpinism                 NaN        NaN
# Archery           173.203085  70.011135
# Art Competitions  174.644068  75.290909
# ...                      ...        ...
# Tug-Of-War        182.480000  95.615385
# Volleyball        186.994822  78.900214
# Water Polo        184.834648  84.566446
# Weightlifting     167.824801  78.726663
# Wrestling         172.358586  75.495570
#
# [66 rows x 2 columns]

# %%
# For each combination of year and season, find the mean height

# categorical: Year + Season
# numeric/data: Height
# agg function: mean

olympics_df.groupby(['Year', 'Season'])['Height'].mean()
# Out:
# Year  Season
# 1896  Summer    172.739130
# 1900  Summer    176.637931
# 1904  Summer    175.788732
# 1906  Summer    178.206226
# 1908  Summer    177.543158
# 1912  Summer    177.447989
# 1920  Summer    175.752282
# 1924  Summer    175.239548
#       Winter    172.213483
# 1928  Summer    175.331770
#       Winter    173.975410
# 1932  Summer    174.371681
#       Winter    173.433673
# 1936  Summer    176.112689
#       Winter    172.705882
# 1948  Summer    176.600190
#       Winter    172.293103
# 1952  Summer    174.183023
#       Winter    173.540000
# 1956  Summer    174.116567
#       Winter    172.433140
# 1960  Summer    173.310287
#       Winter    170.701493
# 1964  Summer    173.690848
#       Winter    172.133674
# 1968  Summer    174.087484
#       Winter    173.289689
# 1972  Summer    174.745758
#       Winter    173.463415
# 1976  Summer    175.053724
#       Winter    174.099032
# 1980  Summer    175.634392
#       Winter    174.991354
# ...

# %%
# For each sport, find the mean + std height.

# categorical: Sport
# numeric/data: Height
# aggregation function: mean + std

olympics_df.groupby('Sport')['Height'].agg(['mean', 'std'])
# Out:
#                         mean        std
# Sport
# Aeronautics              NaN        NaN
# Alpine Skiing     173.489052   7.848716
# Alpinism                 NaN        NaN
# Archery           173.203085   8.442945
# Art Competitions  174.644068   9.286183
# ...                      ...        ...
# Tug-Of-War        182.480000   6.232442
# Volleyball        186.994822  10.456854
# Water Polo        184.834648   8.560613
# Weightlifting     167.824801   9.949635
# Wrestling         172.358586  10.074425
#
# [66 rows x 2 columns]

# %%
# what if we go completely bananas, and use multiple items in each portion of the groupby?

# categorical: Year + Season
# numeric/data: Height + Weight
# aggregation methods: mean + std

olympics_df.groupby(['Year', 'Season'])[['Height', 'Weight']].agg(['mean', 'std'])
# Out:
#                  Height                Weight
#                    mean        std       mean        std
# Year Season
# 1896 Summer  172.739130  11.152349  71.387755  13.819998
# 1900 Summer  176.637931   8.386735  74.556962  12.232520
# 1904 Summer  175.788732   7.875653  72.197279  14.017914
# 1906 Summer  178.206226   7.284956  75.917073  11.954384
# 1908 Summer  177.543158   7.479630  75.386128  12.757573
# 1912 Summer  177.447989   7.228445  73.117450  12.467455
# 1920 Summer  175.752282   7.786053  73.106157  13.585755
# 1924 Summer  175.239548   8.004610  71.812018  12.381760
#      Winter  172.213483   6.256763  69.560976  10.700581
# 1928 Summer  175.331770   8.194031  70.941791  12.128684
#      Winter  173.975410   8.163073  71.625000   8.514381
# 1932 Summer  174.371681   8.636896  70.897980  12.006501
#      Winter  173.433673   7.478563  67.363636   8.496434
# 1936 Summer  176.112689   8.703956  71.630363  12.442215
# ...

# %% [markdown]
# # Pivot tables
#
# Pivot tables are a famous way to summarize data. They basically let us say, given a data frame:
#
# - select one categorical column
# - select a second categorical column
# - select a numeric column
# - select an aggregation method
#
# The result is a data frame with *two* categorical axes, one in the rows and one in the columns
#
# If you want to know the total sales for each country + product line, a pivot table will do that really easily:
#
# ```python
# df.pivot_table(index='country',
#                columns='product_line',
#                values='sales',
#                aggfunc='sum')
# ```
#
# A pivot table is basically a 2D `groupby`. You have to choose two different categorical columns, but once you do, everything else falls into place.

# %%
# I can do a pivot table on the taxi data

# for example, let's create a data frame in which the rows are passenger_count and the columns are payment_type. 
# We can see the distance traveled in the data set for each number of passengers, for each type of payment.

df.pivot_table(index='passenger_count',
               columns='payment_type',
               values='trip_distance',
               aggfunc='mean')
# Out:
# payment_type            1         2          3      4
# passenger_count
# 0                4.600000       NaN        NaN    NaN
# 1                3.408621  2.613389   1.900968  1.718
# 2                3.625507  3.016911  11.700000    NaN
# 3                3.221504  3.493575        NaN  3.600
# 4                4.161136  3.130638        NaN    NaN
# 5                3.518750  2.645050        NaN    NaN
# 6                3.178606  3.161118        NaN    NaN

# %% [markdown]
# # Exercise: Olympic pivots
#
# 1. Create a pivot table in which the rows are `Sport` and the columns are `Sex`. Show the mean height for each intersection.
# 2. Do the same thing for height and weight. What happens if you pass a list of columns, rather than a single column, to `pivot_table`?
#
# There is also a `pivot` method -- basically, ignore it.

# %%
# categorical for index - Sport
# categorical for columns - Sex
# numeric/data - Height
# aggfunc - mean

olympics_df.pivot_table(index='Sport',
                        columns='Sex',
                        values='Height',
                        aggfunc='mean')
# Out:
# Sex                                 F           M
# Sport
# Alpine Skiing              167.221001  177.891374
# Archery                    167.166483  178.477842
# Art Competitions           160.000000  174.896552
# Athletics                  169.285714  179.768303
# Badminton                  168.438519  179.620787
# Baseball                          NaN  182.599291
# Basketball                 182.454836  194.872624
# Beach Volleyball           178.866667  193.290909
# Biathlon                   166.540541  178.856281
# Bobsleigh                  173.181818  181.992015
# Boxing                     168.800000  172.888199
# Canoeing                   169.628995  181.212532
# Cross Country Skiing       166.650819  177.757682
# Curling                    167.520362  180.709251
# Cycling                    168.018629  177.745402
# Diving                     161.173604  171.555352
# Equestrianism              167.875755  176.563172
# Fencing                    168.954292  180.014125
# ...

# %%
# Do the same thing for height and weight. What happens if you pass a list of columns, rather than a single column, to pivot_table?

# categorical for index - Sport
# categorical for columns - Sex
# numeric/data - Height, Weight
# aggfunc - mean

olympics_df.pivot_table(index='Sport',
                        columns='Sex',
                        values=['Height', 'Weight'],
                        aggfunc='mean')
# Out:
#                                Height                 Weight
# Sex                                 F           M          F          M
# Sport
# Alpine Skiing              167.221001  177.891374  62.640307  78.626035
# Archery                    167.166483  178.477842  62.013575  77.066866
# Art Competitions           160.000000  174.896552        NaN  75.290909
# Athletics                  169.285714  179.768303  60.239798  73.839129
# Badminton                  168.438519  179.620787  61.586364  74.362536
# Baseball                          NaN  182.599291        NaN  85.707792
# Basketball                 182.454836  194.872624  73.685170  91.683529
# Beach Volleyball           178.866667  193.290909  68.350943  89.512821
# Biathlon                   166.540541  178.856281  57.306586  72.632123
# Bobsleigh                  173.181818  181.992015  72.804196  90.387385
# Boxing                     168.800000  172.888199  61.836066  65.296280
# ...

# %%
olympics_df.pivot_table(index='Sport',
                        columns='Sex',
                        values=['Height', 'Weight'],
                        aggfunc='max')
# Out:
#                           Height        Weight
# Sex                            F      M      F      M
# Sport
# Alpine Skiing              187.0  200.0   90.0  107.0
# Archery                    185.0  197.0   95.0  130.0
# Art Competitions           160.0  190.0    NaN   93.0
# Athletics                  194.0  208.0  136.0  165.0
# Badminton                  184.0  201.0   90.0   97.0
# Baseball                     NaN  206.0    NaN  120.0
# Basketball                 213.0  226.0  128.0  156.0
# Beach Volleyball           196.0  212.0   81.0  110.0
# Biathlon                   182.0  200.0   72.0   95.0
# Bobsleigh                  194.0  211.0   95.0  145.0
# Boxing                     184.0  208.0   79.0  140.0
# Canoeing                   185.0  205.0   99.0  115.0
# Cross Country Skiing       184.0  200.0   77.0  100.0
# Curling                    184.0  197.0   95.0  105.0
# Cycling                    201.0  201.0   92.0  104.0
# ...

# %% [markdown]
# # Next up
#
# - Joining and merging (i.e., combining two data frames into one)
# - Cleaning our data
# - Plotting
# - AMA + Next steps

# %% [markdown]
# # Look at inflation data -- OECD

# %%
filename = 'bw-175-oecd.csv'

inflation_df = pd.read_csv(filename,
                          usecols=['Reference area', 'Expenditure', 'OBS_VALUE', 'TIME_PERIOD'])

# %%
inflation_df
# Out:
#       Reference area                    Expenditure TIME_PERIOD  OBS_VALUE
# 0            Türkiye  All items non-food non-energy     2006-06  10.253290
# 1            Türkiye  All items non-food non-energy     2006-07  11.408550
# 2            Türkiye  All items non-food non-energy     2006-08   9.732411
# 3            Türkiye  All items non-food non-energy     2006-09  10.485100
# 4            Türkiye  All items non-food non-energy     2006-10  10.614680
# ...              ...                            ...         ...        ...
# 37401        Iceland                          Total     2025-07   4.012321
# 37402        Iceland                          Total     2025-08   3.756847
# 37403        Iceland                          Total     2025-09   4.114132
# 37404        Iceland                          Total     2025-10   4.306931
# 37405        Iceland                          Total     2025-11   3.697201
#
# [37406 rows x 4 columns]

# %%
# what was the mean total inflation in OECD countries for each time period

# categorical - TIME_PERIOD
# numeric - OBS_VALUE
# aggregation method - mean

(
    inflation_df                                   # start with this data frame
    .loc[ pd.col('Expenditure') == 'Total' ]      # keep only the rows for total inflration
    .groupby('TIME_PERIOD')['OBS_VALUE'].mean()    # groupby each time period, and get the mean
    .tail(24)
)
# Out:
# TIME_PERIOD
# 2024-06    4.733121
# 2024-07    4.458883
# 2024-08    3.922322
# 2024-09    3.558880
# 2024-10    3.586547
# 2024-11    3.714024
# 2024-12    3.820361
# 2025-01    3.936904
# 2025-02    3.899391
# 2025-03    3.664658
# 2025-04    3.581792
# 2025-05    3.422223
# 2025-06    3.560631
# 2025-07    3.578969
# 2025-08    3.589346
# 2025-09    3.651191
# 2025-10    3.552562
# 2025-11    3.413828
# 2025-12    3.315499
# 2026-01    2.871634
# 2026-02    2.872103
# 2026-03    3.400966
# 2026-04    3.864099
# 2026-05    3.082412
# Name: OBS_VALUE, dtype: float64

# %%
# let's get the inflation for each country in each time period
# let's do a pivot table!

# index - TIME_PERIOD
# columns - country
# numeric - OBS_VALUE
# aggregation method - mean

(
    inflation_df                                   # start with this data frame
    .loc[ pd.col('Expenditure') == 'Total' ]      # keep only the rows for total inflration
    .pivot_table(index='TIME_PERIOD',
                 columns='Reference area',
                 values='OBS_VALUE',
                 aggfunc='mean')
    .tail(24)
)
# Out:
# Reference area  Austria   Belgium  Bulgaria    Canada     Chile  Costa Rica  \
# TIME_PERIOD
# 2024-06             NaN  3.746674  2.498763  2.671756  4.218052   -0.033757
# 2024-07             NaN  3.642699  2.387787  2.530044  4.628659    0.031875
# 2024-08             NaN  2.860736  2.121861  1.953371  4.770876    0.312504
# 2024-09             NaN  3.060040  1.153117  1.640379  4.160714   -0.135852
# 2024-10             NaN  3.207150  1.846546  2.017654  4.721158   -0.786395
# 2024-11             NaN  3.201764  2.077325  1.889169  4.210277   -0.091823
# 2024-12             NaN  3.156354  2.213665  1.831965  4.561899    0.841719
# 2025-01             NaN  4.087789  3.750952  1.895136  4.935116    1.150493
# 2025-02             NaN  3.552618  4.036996  2.644836  4.730258    1.246541
# 2025-03             NaN  2.906738  4.005991  2.315394  4.868549    1.212584
# 2025-04             NaN  2.538700  3.470720  1.743462  4.523440    0.371890
# ...

# %% [markdown]
# # Joining
#
# It's pretty common for us to work with more than one data frame at a time -- and then to combine them to perform certain analysis. You can imagine having inflation data for countries around the world, and also oil prices for countries around the world, but separate. You can join them together and then perform some analysis.
#
# The way we do that in Pandas is typically with the `join` method. (There is also a `merge` method, and it works on any columns. `join` only works on the indexes.)
#
# The idea is:
#
# - You have one data frame with an index
# - You have another data frame with the same index (roughly speaking)
# - You join them together, and the index remains the same, and the rest of the columns are a combination of the two input data frames.
#
# So if you have a 3-column data frame and a 4-column data frame, and you join them together, you'll have a 7-column data frame.

# %%
oil_prices = DataFrame([[1, 60],
                        [2, 65],
                        [3, 63],
                        [4, 69],
                        [5, 72],
                        [6, 65],
                        [7, 60],
                        [8, 55],
                        [9, 60],
                        [10, 62],
                        [11, 63],
                        [12, 65]],
                      columns=['month', 'price'])
oil_prices
# Out:
#     month  price
# 0       1     60
# 1       2     65
# 2       3     63
# 3       4     69
# 4       5     72
# 5       6     65
# 6       7     60
# 7       8     55
# 8       9     60
# 9      10     62
# 10     11     63
# 11     12     65

# %%
months = DataFrame([[1, 'January'],
                     [2, 'February'],
                     [3, 'March'],
                     [4, 'April'],
                     [5, 'May'],
                     [6, 'June'],
                     [7, 'July'],
                     [8, 'August'],
                     [9, 'September'],
                     [10, 'October'],
                    [11, 'November'],
                     [12, 'December']],
                  columns=['number', 'name'])

months
# Out:
#     number       name
# 0        1    January
# 1        2   February
# 2        3      March
# 3        4      April
# 4        5        May
# 5        6       June
# 6        7       July
# 7        8     August
# 8        9  September
# 9       10    October
# 10      11   November
# 11      12   December

# %%
# we now have two data frames:

# oil_prices, with month (number) and price
# months, with number and name

# how can we join these together?

# 1. We set the index on each to be the common column
# 2. We join them together
# 3. PROFIT!

# %%
(
    oil_prices
    .set_index('month')
).join(
    months
    .set_index('number')
)
# Out:
#        price       name
# month
# 1         60    January
# 2         65   February
# 3         63      March
# 4         69      April
# 5         72        May
# 6         65       June
# 7         60       July
# 8         55     August
# 9         60  September
# 10        62    October
# 11        63   November
# 12        65   December

# %% [markdown]
# # Some examples:
#
# 1. You have a data frame with employee information (name, ID number, department, etc.) and another data frame with salary information (keyed by employee ID number). Joining them together would give you people's names and salaries.
# 2. One data frame with regions (names, countries, etc.) and another data frame with sales figures, using region IDs instead of names
# 3.

# %% [markdown]
# # The big problem with joins
#
# Pandas doesn't allow you to repeat column names. Generally speaking, if you try to create a data frame where more than one column has the same name, you'll get an error.
#
# This happens all the time when we try to join together two different data frames. They'll both have a `name` column or an `id` column. Then what?
#
# `join` has two keyword arguments, `lsuffix` and `rsuffix`. These are added to column names from the left and right, if they'll have a colission.

# %% [markdown]
# # Exercise: Joining
#
# 1. Create a data frame with names of people in your family, and their ages.
# 2. Create another data frame containig the names and shoe sizes of people in your family.
# 3. Use `df.set_index` along with `df.join` to join these two together -- giving you a single data frame whose index is the people's names and whose coumns include `age` and `shoesize`.

# %%
family_df = pd.DataFrame([['Reuven', 55],
                          ['SF', 53],
                          ['ALF', 25],
                          ['SLF', 23],
                          ['ADLF', 20]],
                        columns=['name', 'age'])
family_df
# Out:
#      name  age
# 0  Reuven   55
# 1      SF   53
# 2     ALF   25
# 3     SLF   23
# 4    ADLF   20

# %%
shoe_size_df = pd.DataFrame([['Reuven', 46],
                          ['ADLF', 44],
                          ['ALF', 40],
                          ['SLF', 40],
                          ['SF', 40]],
                           columns=['name', 'shoe_size'])
shoe_size_df
# Out:
#      name  shoe_size
# 0  Reuven         46
# 1    ADLF         44
# 2     ALF         40
# 3     SLF         40
# 4      SF         40

# %%
# how can I combine them?
# there is a merge method, which works with any columns, but I just prefer join

(
    family_df
    .set_index('name')
).join(
    shoe_size_df
    .set_index('name')
)
# Out:
#         age  shoe_size
# name
# Reuven   55         46
# SF       53         40
# ALF      25         40
# SLF      23         40
# ADLF     20         44

# %% [markdown]
# # Cleaning data
#
# Data, when it comes from the real world, can have lots of problems:
#
# - It might have missing values (`NaN`)
# - It might have wrong values
# - It might be irrelevant
#
# Cleaning your data is a massive part of working with it.
#
# The big problem is usually going to be `NaN`. What will you do about it?
#
# - Remove all rows containing `NaN`. That makes for very clean data, but usually also very small data.
# - Remove rows containing `NaN` in particular columns.
# - Replace `NaN` with good values -- maybe the mean, and maybe interpolation
# - Replace bad values with good ones -- replacing strings with integers, for example.

# %%
inflation_df
# Out:
#       Reference area                    Expenditure TIME_PERIOD  OBS_VALUE
# 0            Türkiye  All items non-food non-energy     2006-06  10.253290
# 1            Türkiye  All items non-food non-energy     2006-07  11.408550
# 2            Türkiye  All items non-food non-energy     2006-08   9.732411
# 3            Türkiye  All items non-food non-energy     2006-09  10.485100
# 4            Türkiye  All items non-food non-energy     2006-10  10.614680
# ...              ...                            ...         ...        ...
# 37401        Iceland                          Total     2025-07   4.012321
# 37402        Iceland                          Total     2025-08   3.756847
# 37403        Iceland                          Total     2025-09   4.114132
# 37404        Iceland                          Total     2025-10   4.306931
# 37405        Iceland                          Total     2025-11   3.697201
#
# [37406 rows x 4 columns]

# %%
# Remove all rows containing NaN. That makes for very clean data, but usually also very small data.

inflation_df = pd.read_csv('bw-175-oecd.csv')
inflation_df.dropna()  # remove all rows containing any NaN at all
# Out:
# Empty DataFrame
# Columns: [STRUCTURE, STRUCTURE_ID, STRUCTURE_NAME, ACTION, REF_AREA, Reference area, FREQ, Frequency of observation, METHODOLOGY, Methodology, MEASURE, Measure, UNIT_MEASURE, Unit of measure, EXPENDITURE, Expenditure, ADJUSTMENT, Adjustment, TRANSFORMATION, Transformation, TIME_PERIOD, Time period, OBS_VALUE, Observation value, OBS_STATUS, Observation status, UNIT_MULT, Unit multiplier, BASE_PER, Base period, DURABILITY, Durability, DECIMALS, Decimals]
# Index: []
#
# [0 rows x 34 columns]

# %%
# Remove rows containing NaN in particular columns.

inflation_df = pd.read_csv('bw-175-oecd.csv')
inflation_df.dropna(subset=['OBS_VALUE'])
# Out:
#       STRUCTURE                                       STRUCTURE_ID  \
# 0      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 1      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 2      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 3      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 4      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# ...         ...                                                ...
# 37401  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 37402  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 37403  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 37404  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 37405  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
#
#                                          STRUCTURE_NAME ACTION REF_AREA  \
# 0      Consumer price indices (CPIs,HICPs), COICOP 2018      I      TUR
# ...

# %%
# Replace NaN with good values -- maybe the mean, and maybe interpolation
# remember fillna?

inflation_df.fillna(0)
# Out:
#       STRUCTURE                                       STRUCTURE_ID  \
# 0      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 1      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 2      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 3      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 4      DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# ...         ...                                                ...
# 37401  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 37402  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 37403  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 37404  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
# 37405  DATAFLOW  OECD.SDD.TPS:DSD_PRICES_COICOP2018@DF_PRICES_C...
#
#                                          STRUCTURE_NAME ACTION REF_AREA  \
# 0      Consumer price indices (CPIs,HICPs), COICOP 2018      I      TUR
# ...

# %%
# interpolation -- if there's a NaN, then replace it with the mean of the two values around it. If there are two NaN
# values in a row, then use the real values around them, and step it up from one to the other. This is only useful 
# where interpolation makes sense: Temperature, stock prices, oil prices. 

# If you have a data set of winning lottery numbers, interpolation is a very bad way to try to get
# any lottery numbers you're missing.

import numpy as np
s = pd.Series([10, 20, np.nan, 40, 30, np.nan, 50, 60, np.nan, 80])
s.interpolate()
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    30.0
# 5    40.0
# 6    50.0
# 7    60.0
# 8    70.0
# 9    80.0
# dtype: float64

# %%
# Replace bad values with good ones -- replacing strings with integers, for example.

# %% [markdown]
# # Removing outliers
#
# Many times, you have values in your entire data frame -- but some of them are just wacky, or (if included in calculations) would lead to real problems.
#
# If you have a computer system that's tracking logins, and you want to figure out how many times/hour people log in, and then there's a massive cyber attack, you don't want to take those into account!
#
# Or: You do want to take those into account, if you're a security professional looking for cyber attacks.
#
# How can you find outliers? Typically, you can use loc and pd.col and mean to look for values more than the mean + 2 standard deviations.

# %% [markdown]
# # Next up
#
# 1. Plotting and visualization
# 2. AMA (ask me anything) and next steps

# %% [markdown]
# # Plotting and visualization
#
# The best-known and most flexible plotting library in the Python world is called Matplotlib. It can do anything you want, any sort of plot.
#
# It's also really hard to understand and use.
#
# The good news is that Pandas provides methods that hide most of the complexity of Matplotlib. So you can get good plots with minimum effort.
#
# We're going to see and use the Pandas methods for Matplotlib, which will be running behind the scenes, but we won't see it.

# %%
# here we have mean inflation, across all countries, for every year-month combination
# it gives us a series
# on a series (or a data frame), we can invoke the "plot" method
# that, inside of Jupyter, displays a plot. However, we're best off
# telling it what kind of plot to use -- the easiest, line plot is .plot.line

(
    inflation_df                                   # start with this data frame
    .loc[ pd.col('Expenditure') == 'Total' ]      # keep only the rows for total inflration
    .groupby('TIME_PERIOD')['OBS_VALUE'].mean()    # groupby each time period, and get the mean
    .plot.line()
)


# when we plot a series using .plot.line, the index is used for the x axis, 
# and the values are used for the y axis
# Out:
# <Axes: xlabel='TIME_PERIOD'>

# %%
# what happens if I invoke .plot.line on a data frame?
# I get one line per column


(
    inflation_df                                   # start with this data frame
    .loc[ pd.col('Expenditure') == 'Total' ]      # keep only the rows for total inflration
    .groupby('TIME_PERIOD')['OBS_VALUE'].agg(['mean', 'median'])
    .plot.line()
)
# Out:
# <Axes: xlabel='TIME_PERIOD'>

# %%
# what other kinds of plots can we do?
# common: bar plots

# it's like a line plot, but not connected

(
    inflation_df                                   # start with this data frame
    .loc[ pd.col('Expenditure') == 'Total' ]      # keep only the rows for total inflration
    .groupby('TIME_PERIOD')['OBS_VALUE'].mean()
    .plot.bar()
)
# Out:
# <Axes: xlabel='TIME_PERIOD'>

# %%
(
    shoe_size_df
    .set_index('name')
    .plot.bar()
)
# Out:
# <Axes: xlabel='name'>

# %%
# box-and-whiskers plot, aka "boxplot" -- it's a graphical version of the "describe" method
# meaning: it shows min, 25%, median, 75%, and max. If there are outliers, then they are drawn with dots

shoe_size_df.plot.box()
# Out:
# <Axes: >

# %%
olympics_df['Height'].plot.box()
# Out:
# <Axes: >

# %%
olympics_df[['Height', 'Weight']].plot.box()
# Out:
# <Axes: >

# %%
# pie charts!
# this is useful to show the proportional distribution of a known whole.

# typically, we'll use it with value_counts

(
    shoe_size_df
    ['shoe_size']
    .value_counts()
    .plot.pie(title='Distribution of shoe sizes in Reuven\'s family')
)
# Out:
# <Axes: title={'center': "Distribution of shoe sizes in Reuven's family"}>

# %%
shoe_size_df['shoe_size'].plot.pie()  # common, dumb mistake
# Out:
# <Axes: >

# %%
# histograms -- how often do values appear?

shoe_size_df['shoe_size'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# my favorite, and a really useful one, is scatterplots
# This is a great way to compare two values for one record

olympics_df.plot.scatter(x='Height', y='Weight', c='Sex', cmap='autumn')
# Out:
# /Users/reuven/Courses/Current/OReilly-PythonData-2026-06/.venv/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:1388: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Height', ylabel='Weight'>

# %% [markdown]
# # Summarize plots:
#
# - line plots, with `.plot.line`
# - bar plots, with `.plot.bar`
# - pie charts, with `.plot.pie` (only use after `value_counts`!)
# - histograms, with `.plot.hist`
# - boxplots, with `.plot.box`
# - scatterplots, with `.plot.scatter`

# %% [markdown]
# # Exercise: Plotting practice
#
# 1. Load the taxi data into a data frame
# 2. Create a histogram showing how often each `total_amount` shows up in the data.
# 3. Create a pie plot showing how often each `passenger_count` appears in the data.
# 4. Show a scatterplot comparing `trip_distance` and `total_amount`. Before you plot, think what the correlation might look like, and then plot, and tell us if you were right.

# %%
# Create a histogram showing how often each total_amount shows up in the data.

df['total_amount'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Create a pie plot showing how often each passenger_count appears in the data.
# Show a scatterplot comparing trip_distance and total_amount. Before you plot, think what the correlation might look like, and then plot, and tell us if you were right.
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1         2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2         2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3         2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4         1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.63        -73.954430        40.764141           1
# 1           0.46        -73.971443        40.758942           1
# 2           0.87        -73.978111        40.738434           1
# 3           2.13        -73.945892        40.773529           1
# 4           1.40        -73.979088        40.776772           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...
